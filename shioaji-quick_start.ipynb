# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/seagarwu/mynotebooks/blob/main/shioaji/shioaji_onlinedoc/shioaji-quick_start.ipynb)

# %% [markdown]
# # [Overview](https://sinotrade.github.io/)

# %% [markdown]
# # Quick Start

# %% [markdown]
# ## Initialization

# %%
import shioaji as sj
import getpass as gp

api = sj.Shioaji()
user_id, user_pass = gp.getpass("USER ID: "), gp.getpass("USER PASS: ")
accounts = api.login(user_id, user_pass)
# Out:
# Response Code: 0 | Event Code: 0 | Info: host '203.66.91.161:80', hostname '203.66.91.161:80' IP 203.66.91.161:80 (host 1 of 1) (host connection attempt 1 of 1) (total connection attempt 1 of 1) | Event: Session up

# %%
import tkinter as tk
from tkinter import filedialog

root = tk.Tk()
root.withdraw()
file_path = filedialog.askopenfilename()

api.activate_ca(
    ca_path = file_path,
    ca_passwd = user_pass,
    person_id = user_id,
)
# Out:
# True

# %% [markdown]
# Just import our API library like other popular python library and new the instance to start using our API. Login your account and activate the certification then you can start placing order.

# %% [markdown]
# ## Streaming Market Data

# %%
api.quote.unsubscribe(api.Contracts.Stocks["2330"], quote_type="tick")
api.quote.unsubscribe(api.Contracts.Stocks["2330"], quote_type="bidask")
api.quote.unsubscribe(api.Contracts.Futures["MXFD2"], quote_type="tick")
api.quote.unsubscribe(api.Contracts.Futures["MXFD2"], quote_type="bidask")
# Out:
# Q/TFE/MXFD2 {'AskPrice': [17324.0, 17325.0, 17326.0, 17327.0, 17328.0], 'AskVolSum': 228, 'AskVolume': [16, 65, 45, 32, 70], 'BidPrice': [17323.0, 17322.0, 17321.0, 17320.0, 17319.0], 'BidVolSum': 89, 'BidVolume': [1, 15, 20, 42, 11], 'Code': 'MXFD2', 'Date': '2022/04/09', 'DiffAskVol': [-4, 0, 0, 0, 0], 'DiffAskVolSum': 0, 'DiffBidVol': [0, 1, 0, 0, 0], 'DiffBidVolSum': 0, 'FirstDerivedAskPrice': 17326.0, 'FirstDerivedAskVolume': 8, 'FirstDerivedBidPrice': 17320.0, 'FirstDerivedBidVolume': 1, 'TargetKindPrice': 17284.54, 'Time': '00:28:53.628000'}
# Q/TFE/MXFD2 {'AskPrice': [17324.0, 17325.0, 17326.0, 17327.0, 17328.0], 'AskVolSum': 228, 'AskVolume': [16, 65, 45, 32, 70], 'BidPrice': [17323.0, 17322.0, 17321.0, 17320.0, 17319.0], 'BidVolSum': 91, 'BidVolume': [1, 17, 20, 42, 11], 'Code': 'MXFD2', 'Date': '2022/04/09', 'DiffAskVol': [0, 0, 0, 0, 0], 'DiffAskVolSum': 0, 'DiffBidVol': [0, 2, 0, 0, 0], 'DiffBidVolSum': 0, 'FirstDerivedAskPrice': 17326.0, 'FirstDerivedAskVolume': 7, 'FirstDerivedBidPrice': 17320.0, 'FirstDerivedBidVolume': 1, 'TargetKindPrice': 17284.54, 'Time': '00:28:53.753000'}
# Response Code: 200 | Event Code: 16 | Info: MKT/*/TSE/2330 | Event: Subscribe or Unsubscribe ok
# Response Code: 200 | Event Code: 16 | Info: QUT/*/TSE/2330 | Event: Subscribe or Unsubscribe ok
# Response Code: 200 | Event Code: 16 | Info: L/*/MXFD2 | Event: Subscribe or Unsubscribe ok
# Response Code: 200 | Event Code: 16 | Info: Q/*/MXFD2 | Event: Subscribe or Unsubscribe ok

# %%
api.quote.subscribe(api.Contracts.Stocks["2330"], quote_type="tick")
api.quote.subscribe(api.Contracts.Stocks["2330"], quote_type="bidask")
api.quote.subscribe(api.Contracts.Futures["MXFD2"], quote_type="tick")
api.quote.subscribe(api.Contracts.Futures["MXFD2"], quote_type="bidask")

# %%
api.quote.subscribe(api.Contracts.Futures["MXFD2"], quote_type="tick")
# Out:
# Response Code: 200 | Event Code: 16 | Info: Subscription Already Exists - Topic 'L/*/MXFD2' Subscribe: Response code: '400'; Flags: 'c';  | Event: Subscribe or Unsubscribe ok

# %% [markdown]
# Subscribe the real time market data. Simplely pass contract into quote `subscribe` function and give the quote type will receive the streaming data.
# > **Quote Type**<br>
#
# > Currently we support two quote type you can see in `shioaji.constent.QuoteType`. The best way to use that is directly pass this enum into `subscribe` function.

# %% [markdown]
# ## Place Order

# %%
# 會實際下單(證券)，請小心! (但我沒有證券帳號，所以下單會error!)
contract = api.Contracts.Stocks["2330"]
order = api.Order(
    price=1,
    quantity=1,
    action=sj.constant.Action.Buy,
    price_type=sj.constant.StockPriceType.LMT,
    order_type=sj.constant.StockOrderType.Common,
)
trade = api.place_order(contract, order)

# %%
# 會實際下單(期貨)，請小心!
contract = api.Contracts.Futures["MXFD2"]
order = api.Order(
    price=16000,
    quantity=1,
    action=sj.constant.Action.Buy,
    price_type=sj.constant.StockPriceType.LMT,
    order_type=sj.constant.StockOrderType.Common,
)
trade = api.place_order(contract, order)
# Out:
# OrderState.FOrder {'operation': {'op_type': 'New', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '1212f219', 'seqno': '551182', 'ordno': 'tA0JX', 'account': {'account_type': 'F', 'person_id': '', 'broker_id': 'F002002', 'account_id': '8070913', 'signed': True}, 'action': 'Buy', 'price': 16000.0, 'quantity': 1, 'order_type': 'ROD', 'price_type': 'LMT', 'market_type': 'Night', 'oc_type': 'New', 'subaccount': '', 'combo': False}, 'status': {'id': '1212f219', 'exchange_ts': 1649348538, 'modified_price': 0.0, 'cancel_quantity': 0, 'order_quantity': 1, 'web_id': 'Z'}, 'contract': {'security_type': 'FUT', 'code': 'MXF', 'exchange': 'TIM', 'delivery_month': '202204', 'delivery_date': '', 'strike_price': 0.0, 'option_right': 'Future'}}
# OrderState.FOrder {'operation': {'op_type': 'Cancel', 'op_code': '00', 'op_msg': ''}, 'order': {'id': '1212f219', 'seqno': '551182', 'ordno': 'tA0JX', 'account': {'account_type': 'F', 'person_id': '', 'broker_id': 'F002002', 'account_id': '8070913', 'signed': True}, 'action': 'Buy', 'price': 16000.0, 'quantity': 1, 'order_type': 'ROD', 'price_type': 'CXL', 'market_type': 'Night', 'oc_type': 'New', 'subaccount': '', 'combo': False}, 'status': {'id': '1212f219', 'exchange_ts': 1649348556, 'modified_price': 0.0, 'cancel_quantity': 1, 'order_quantity': 1, 'web_id': 'I'}, 'contract': {'security_type': 'FUT', 'code': 'MXF', 'exchange': 'TIM', 'delivery_month': '202204', 'delivery_date': '', 'strike_price': 0.0, 'option_right': 'Future'}}

# %% [markdown]
# Like the above subscribing market data using the contract, then need to define the order. Pass them into `place_order` function, then it will return the trade that describe the status of your order.

# %% [markdown]
# ## Conclusion
# This quickstart demonstrates how easy to use our package for native Python users. Unlike many other trading API is hard for Python developer. We focus on making more pythonic trading API for our users.

# %% [markdown]
# ---
# ### Next: [Tutorial-User Guide / Login](shioaji-tutorial_user_guide.ipynb)
